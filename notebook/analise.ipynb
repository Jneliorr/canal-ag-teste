# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Nelio\Documents\GitHub\canal-ag-teste\data\raw\Clientes.csv')
df
# Out:
#    ID_Cliente              Nome_Cliente               Cidade Estado
# 0        C001              Enzo Azevedo       Nunes Paulista     AP
# 1        C002              Miguel Lopes                Sales     MG
# 2        C003         Laís da Conceição       Cunha de Goiás     SC
# 3        C004      Maria Alice Ferreira       Nunes da Praia     ES
# 4        C005        Luiz Gustavo Sales               Barros     AM
# 5        C006       Pedro Lucas da Cruz    Campos das Flores     MG
# 6        C007             Letícia Souza        Vieira do Sul     RO
# 7        C008       Srta. Nina Teixeira      Mendes do Campo     MA
# 8        C009               Bruna Ramos             Ferreira     PE
# 9        C010  Luiz Fernando Cavalcanti      Santos do Oeste     BA
# 10       C011         Sr. Marcelo Souza              Martins     PR
# 11       C012    Carlos Eduardo Moreira      Duarte do Norte     ES
# 12       C013         Ana Júlia Cardoso   Campos de Teixeira     SP
# ...

# %%
df = pd.read_csv(r'C:\Users\Nelio\Documents\GitHub\canal-ag-teste\data\raw\Produtos.csv')
df
# Out:
#    ID_Produto              Nome_Produto    Categoria
# 0        P001             Tempore Culpa  Eletrônicos
# 1        P002               Alias Harum  Informática
# 2        P003         Exercitationem Et  Informática
# 3        P004         Deserunt Corporis  Eletrônicos
# 4        P005        Veritatis Quisquam   Escritório
# 5        P006             Commodi Rerum  Informática
# 6        P007              Nisi Aliquid  Informática
# 7        P008       Aliquam Consectetur  Informática
# 8        P009              Esse Eveniet  Eletrônicos
# 9        P010                  Quae Sed  Informática
# 10       P011             Alias Ratione  Eletrônicos
# 11       P012                Eius Totam  Eletrônicos
# 12       P013       Voluptates Quisquam  Eletrônicos
# 13       P014                 Nihil Est  Informática
# 14       P015     Occaecati Repudiandae  Eletrônicos
# 15       P016                    Hic Ab   Escritório
# 16       P017         Dolore Voluptatem  Informática
# ...

# %%
df = pd.read_csv(r'C:\Users\Nelio\Documents\GitHub\canal-ag-teste\data\raw\Vendas.csv')
df
# Out:
#     ID_Venda        Data ID_Produto ID_Cliente ID_Vendedor  Quantidade  \
# 0       1001  2025-02-21       P041       C045        V036           4
# 1       1002  2025-05-11       P050       C050        V004           4
# 2       1003  2025-05-26       P021       C026        V018           2
# 3       1004  2025-03-17       P037       C046        V021           4
# 4       1005  2025-02-25       P026       C042        V030           3
# 5       1006  2025-05-24       P016       C048        V036           9
# 6       1007  2024-12-31       P038       C028        V038           7
# 7       1008  2025-04-24       P009       C033        V032           2
# 8       1009  2025-05-17       P008       C010        V041           3
# 9       1010  2025-03-03       P028       C039        V005           7
# 10      1011  2025-02-26       P030       C034        V017           9
# 11      1012  2025-01-20       P001       C044        V047           2
# ...

# %%
df = pd.read_csv(r'C:\Users\Nelio\Documents\GitHub\canal-ag-teste\data\raw\Vendedores.csv')
df
# Out:
#    ID_Vendedor                Nome_Vendedor         Equipe
# 0         V001              Dr. Raul Farias  Equipe Centro
# 1         V002        Davi Lucca Cavalcanti     Equipe Sul
# 2         V003               Alícia Ribeiro   Equipe Norte
# 3         V004                Eduardo Ramos  Equipe Centro
# 4         V005           Dr. Enzo das Neves     Equipe Sul
# 5         V006               Rafael da Mota  Equipe Centro
# 6         V007               Helena Freitas   Equipe Norte
# 7         V008                Vitor Freitas     Equipe Sul
# 8         V009           Dr. Renan Teixeira   Equipe Norte
# 9         V010  Sr. Carlos Eduardo Ferreira  Equipe Centro
# 10        V011              Nathan Ferreira     Equipe Sul
# 11        V012                 Calebe Pinto  Equipe Centro
# 12        V013            Dr. Leandro Silva  Equipe Centro
# 13        V014           João Pedro da Mota     Equipe Sul
# 14        V015                Augusto Pinto  Equipe Centro
# ...
